# %% [markdown]
# # **LLM CALL**

# %%
import os
from groq import Groq
from dotenv import load_dotenv

load_dotenv()

client = Groq(
    api_key=os.environ.get("GROQ_API_KEY"),
)

chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content": "Tell me a joke about programming.",
        }
    ],
    model="llama-3.3-70b-versatile",
)

print(chat_completion.choices[0].message.content)
# Out:
# Why do programmers prefer dark mode?
#
# Because light attracts bugs.

# %%
from langchain_groq import ChatGroq
import os
from dotenv import load_dotenv

# Load environment variables from .env
load_dotenv()

# Check API key
if os.environ.get("GROQ_API_KEY"):
    print("Bro API KEY Variable exists")
else:
    raise ValueError("GROQ_API_KEY not found")

# Initialize Groq LLM
llm_groq = ChatGroq(
    model="llama-3.3-70b-versatile",
    temperature=0
)

# Invoke model
response = llm_groq.invoke("Bro, tell me a fun fact")

print(response.content)
# Out:
# Bro API KEY Variable exists
# Did you know that there's a species of jellyfish that's immortal? The Turritopsis dohrnii, also known as the "immortal jellyfish," can transform its body into a younger state through a process called transdifferentiation. It can essentially revert back to its polyp stage, which is the juvenile form of a jellyfish, and then grow back into an adult again. This process can be repeated indefinitely, making it theoretically immortal. How cool is that, bro?

# %%
from langchain.chat_models import init_chat_model
from dotenv import load_dotenv
import os

load_dotenv()

if os.environ.get("GROQ_API_KEY"):
    print("Bro API KEY Variable exists")
else:
    raise ValueError("GROQ_API_KEY not found")

llm_groq = init_chat_model(
    model="llama-3.3-70b-versatile",
    model_provider="groq"
)

response = llm_groq.invoke("Hello bro, how are you?").content

print(response)
# Out:
# Bro API KEY Variable exists
# Hello. I'm just a language model, so I don't have emotions or feelings like humans do, but I'm functioning properly and ready to help with any questions or topics you'd like to discuss. How can I assist you today?
